# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('./data/Telco_customer_churn_adapted_v2.xlsx')

# %%
df.head()
# Out:
#    Customer ID  Tenure Months Location Device Class Games Product  \
# 0            0              2  Jakarta      Mid End           Yes
# 1            1              2  Jakarta     High End            No
# 2            2              8  Jakarta     High End            No
# 3            3             28  Jakarta     High End            No
# 4            4             49  Jakarta     High End            No
#
#   Music Product Education Product Call Center Video Product Use MyApp  \
# 0           Yes                No          No            No        No
# 1            No                No          No            No        No
# 2            No               Yes          No           Yes       Yes
# 3            No               Yes         Yes           Yes       Yes
# 4           Yes               Yes          No           Yes       Yes
#
#    Payment Method  Monthly Purchase (Thou. IDR) Churn Label   Longitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer ID                   7043 non-null   int64
#  1   Tenure Months                 7043 non-null   int64
#  2   Location                      7043 non-null   object
#  3   Device Class                  7043 non-null   object
#  4   Games Product                 7043 non-null   object
#  5   Music Product                 7043 non-null   object
#  6   Education Product             7043 non-null   object
#  7   Call Center                   7043 non-null   object
#  8   Video Product                 7043 non-null   object
#  9   Use MyApp                     7043 non-null   object
#  10  Payment Method                7043 non-null   object
#  11  Monthly Purchase (Thou. IDR)  7043 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# Customer ID                     0
# Tenure Months                   0
# Location                        0
# Device Class                    0
# Games Product                   0
# Music Product                   0
# Education Product               0
# Call Center                     0
# Video Product                   0
# Use MyApp                       0
# Payment Method                  0
# Monthly Purchase (Thou. IDR)    0
# Churn Label                     0
# Longitude                       0
# Latitude                        0
# CLTV (Predicted Thou. IDR)      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Customer ID  Tenure Months  Monthly Purchase (Thou. IDR)    Longitude  \
# count  7043.000000    7043.000000                   7043.000000  7043.000000
# mean   3521.000000      32.371149                     84.190200   107.043246
# std    2033.283305      24.559481                     39.117061     0.358316
# min       0.000000       0.000000                     23.725000   106.816666
# 25%    1760.500000       9.000000                     46.150000   106.816666
# 50%    3521.000000      29.000000                     91.455000   106.816666
# 75%    5281.500000      55.000000                    116.805000   107.609810
# max    7042.000000      72.000000                    154.375000   107.609810
#
#           Latitude  CLTV (Predicted Thou. IDR)
# count  7043.000000                 7043.000000
# mean     -6.404184                 5720.384481
# std       0.322898                 1537.974298
# min      -6.914744                 2603.900000
# ...

# %%
# Visualisasi untuk kolom 'Tenure Months'
plt.hist(df['Tenure Months'], bins=20, edgecolor='black')
plt.title('Distribution of Tenure Months')
plt.xlabel('Tenure Months')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Device Class'
df['Device Class'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Device Class')
plt.xlabel('Device Class')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Payment Method'
df['Payment Method'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Location'
df['Location'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Location')
plt.xlabel('Location')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Games Product'
df['Games Product'].value_counts().plot(kind='bar', color='blue', edgecolor='black')
plt.title('Distribution of Games Product')
plt.xlabel('Games Product')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Music Product'
df['Music Product'].value_counts().plot(kind='bar', color='cyan', edgecolor='black')
plt.title('Distribution of Music Product')
plt.xlabel('Music Product')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Education Product'
df['Education Product'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Education Product')
plt.xlabel('Education Product')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Call Center'
df['Call Center'].value_counts().plot(kind='bar', color='yellow', edgecolor='black')
plt.title('Distribution of Call Center')
plt.xlabel('Call Center')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Video Product'
df['Video Product'].value_counts().plot(kind='bar', color='red', edgecolor='black')
plt.title('Distribution of Video Product')
plt.xlabel('Video Product')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Use MyApp'
df['Use MyApp'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Use MyApp')
plt.xlabel('Use MyApp')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Churn Label'
df['Churn Label'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Churn Label')
plt.xlabel('Churn Label')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Longitude'
df['Longitude'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Longitude')
plt.xlabel('Longitude')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Visualisasi untuk kolom 'Longitude'
df['Longitude'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Longitude')
plt.xlabel('Longitude')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Boxplot untuk 'CLTV (Predicted Thou. IDR)'
plt.boxplot(df['CLTV (Predicted Thou. IDR)'])
plt.title('Boxplot of CLTV (Predicted Thou. IDR)')
plt.ylabel('CLTV (Predicted Thou. IDR)')
plt.show()

# %%
# Boxplot untuk 'Monthly Purchase'
plt.boxplot(df['Monthly Purchase (Thou. IDR)'])
plt.title('Boxplot of Monthly Purchase')
plt.ylabel('Monthly Purchase (Thou)')
plt.show()

# %%
# Menghitung matriks korelasi
corr_matrix = df.corr()

# Membuat heatmap
plt.figure(figsize=(12, 9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Feature Correlations')
plt.show()

# %%
# Membuat histplot untuk 'Monthly Purchase (Thou. IDR)'
plt.figure(figsize=(12, 6))
sns.histplot(df['Monthly Purchase (Thou. IDR)'], kde=True, bins=30)
plt.title('Histogram of Monthly Purchase (Thou. IDR)')
plt.xlabel('Monthly Purchase (Thou. IDR)')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Membuat histplot untuk 'CLTV (Predicted Thou. IDR)'
plt.figure(figsize=(12, 6))
sns.histplot(df['CLTV (Predicted Thou. IDR)'], kde=True, bins=30)
plt.title('Histogram of CLTV (Predicted Thou. IDR)')
plt.xlabel('CLTV (Predicted Thou. IDR)')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# one-hot encoding (categorical variables with more than two levels)
one_hot_encoding_columns = ['Games Product', 'Device Class', 'Music Product', 'Payment Method', 'Education Product', 
                            'Use MyApp', 'Video Product',  'Call Center', 'Longitude', 'Latitude', 'Location', 'Churn Label']

# encode categorical variables with more than two levels using one-hot encoding
df = pd.get_dummies(df, columns = one_hot_encoding_columns)

# %%
df = df.drop('Customer ID', axis=1)

# %%
from sklearn.cluster import KMeans

# %%
# Mencari jumlah cluster optimal dengan metode elbow
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

# Plot untuk melihat 'elbow'
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Setelah menentukan jumlah cluster optimal, buat model KMeans
optimal_clusters = 3  # misalnya didapatkan 3 dari plot elbow
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(df)

# %%
# Grouping data by cluster
df_clf = df.groupby(['Cluster'], as_index=False).mean()
df_clf = round(df_clf, 3)
df_clf.head()
# Out:
#    Cluster  Tenure Months  Monthly Purchase (Thou. IDR)  \
# 0        0         33.653                        83.934
# 1        1         18.399                        79.173
# 2        2         41.058                        88.000
#
#    CLTV (Predicted Thou. IDR)  Games Product_No  \
# 0                    5638.742             0.489
# 1                    3624.698             0.582
# 2                    7287.048             0.444
#
#    Games Product_No internet service  Games Product_Yes  \
# 0                              0.227              0.284
# 1                              0.213              0.205
# 2                              0.209              0.347
#
#    Device Class_High End  Device Class_Low End  Device Class_Mid End  ...  \
# 0                  0.433                 0.227                 0.340  ...
# 1                  0.435                 0.213                 0.352  ...
# 2                  0.449                 0.209                 0.342  ...
#
# ...
